# %% [markdown]
# <a href="https://colab.research.google.com/github/Juananorton/Entrega/blob/main/GoogleColab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Este es mi primer cuaderno
#
# Aqui voy a mezclar código MarkDown con operaciones matemáticas
#
# - Suma
# - Resta
# - División
# - Multiplicación

# %%
a = 3
b = 9
a + b
# Out:
# 12

# %%
c = 10
d = -8
d - c

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# a = 1:100
# b = a^2
# plot(a, b, main='presion del gas crítico', xlab='Volumen', ylab='presión', type='b', col='blue')
